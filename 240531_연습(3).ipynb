# %%
import pandas as pd

stu_df = pd.read_csv("Student_Marks.csv")
stu_df
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
stu_df.describe()
# Out:
#        number_courses  time_study       Marks
# count      100.000000  100.000000  100.000000
# mean         5.290000    4.077140   24.417690
# std          1.799523    2.372914   14.326199
# min          3.000000    0.096000    5.609000
# 25%          4.000000    2.058500   12.633000
# 50%          5.000000    4.022000   20.059500
# 75%          7.000000    6.179250   36.676250
# max          8.000000    7.957000   55.299000

# %%
stu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  100 non-null    int64
#  1   time_study      100 non-null    float64
#  2   Marks           100 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
stu_df.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %%
stu_df.tail()
# Out:
#     number_courses  time_study   Marks
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357

# %%
stu_df.corr()
# Out:
#                 number_courses  time_study     Marks
# number_courses        1.000000    0.204844  0.417335
# time_study            0.204844    1.000000  0.942254
# Marks                 0.417335    0.942254  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(ncols=2, figsize=(12,6))
sns.scatterplot(data=stu_df, x="number_courses", y ="Marks", ax=ax[0])
sns.scatterplot(data=stu_df, x="time_study", y="Marks", ax=ax[1])
plt.show()

# %%
from sklearn.model_selection import train_test_split
x = stu_df.drop("Marks",axis=1)
y = stu_df["Marks"]
X_train, X_test, Y_train, Y_test = train_test_split(x, y,test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr_model = LinearRegression()

# %%
lr_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
lr_pred=lr_model.predict(X_test)

# %%
r2_score(lr_pred, Y_test)
# Out:
# 0.9219617777759717

# %%
mean_squared_error(lr_pred, Y_test)
# Out:
# 14.200726136374552

# %%
sns.regplot(x=stu_df["time_study"], y=stu_df["Marks"])
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
